# %% [markdown]
# 5 Number Theory and Box Plot

# %%
## Minimum, Maximum, Median(Q2), Q1, Q3, IQR

# %%
import numpy as np

# %%
lst_Marks = [45, 32, 56,75,59,68,88,90,99,74,75]
minimum,Q1,median,Q3,maximum = np.quantile(lst_Marks, [0,0.25,0.50,0.75,1.0])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(32.0),
#  np.float64(57.5),
#  np.float64(74.0),
#  np.float64(81.5),
#  np.float64(99.0))

# %%
IQR = Q3 - Q1
print(IQR)
# Out:
# 24.0

# %%
lower_fence = Q1-1.5*(IQR)
Higher_fence = Q3+1.5*(IQR)

# %%
lower_fence 
Higher_fence
# Out:
# np.float64(117.5)

# %%
lower_fence
# Out:
# np.float64(21.5)

# %%
# Box Plot
import seaborn as sns

# %%
sns.boxplot(lst_Marks)
# Out:
# <Axes: >

# %%
lst_Marks = [-81,12,10,45, 32, 56,75,59,68,88,90,99,74,75,150]
sns.boxplot(lst_Marks)
# Out:
# <Axes: >
